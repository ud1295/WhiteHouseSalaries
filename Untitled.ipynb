# %%
import pandas as pd
import numpy as np
% matplotlib inline

# %% [markdown]
# ## Data Loading (read_csv)

# %%
Obama= pd.read_csv('./salaries dataset/obama_staff_salaries.csv')
Trump= pd.read_csv('./salaries dataset/white_house_2017_salaries.csv')

# %%
Obama
# Out:
#                               name    status      salary  pay_basis  \
# 0             Abraham, Yohannes A.  Employee   $40000.00  Per Annum
# 1                  Abrams, Adam W.  Employee   $65000.00  Per Annum
# 2                    Adams, Ian H.  Employee   $36000.00  Per Annum
# 3                  Agnew, David P.  Employee   $92000.00  Per Annum
# 4               Ahrens, Rebecca A.  Employee   $42800.00  Per Annum
# 5             Aldy, Jr., Joseph E.  Employee  $130500.00  Per Annum
# 6            Alvarado, Lissette A.  Employee   $57000.00  Per Annum
# 7             Amorsingh, Lucius L.  Employee   $54768.00  Per Annum
# 8              Anderson, Amanda D.  Employee   $55000.00  Per Annum
# 9             Anderson, Charles D.  Employee   $50000.00  Per Annum
# 10              Anello, Russell M.  Employee   $65000.00  Per Annum
# 11           Aniskoff, Paulette L.  Employee   $72000.00  Per Annum
# 12            Armbruster, Sally M.  Employee   $36000.00  Per Annum
# ...

# %%
Trump
# Out:
#                             NAME    STATUS        SALARY  PAY BASIS  \
# 0           Alexander, Monica K.  Employee   $56,000.00   Per Annum
# 1          Ambrosini, Michael J.  Employee   $95,000.00   Per Annum
# 2                 Amin, Stacy C.  Employee  $140,000.00   Per Annum
# 3           Andersen, Whitney N.  Employee   $94,000.00   Per Annum
# 4         Anderson, Alexander J.  Employee   $77,000.00   Per Annum
# 5         Angelson, Alexander J.  Employee   $95,000.00   Per Annum
# 6             Augustine, Rene I.  Employee  $140,000.00   Per Annum
# 7                Baitel, Rachael  Employee   $62,000.00   Per Annum
# 8           Baldwin, Brittany L.  Employee   $70,000.00   Per Annum
# 9               Banks, George D.  Employee  $140,000.00   Per Annum
# 10            Bannon, Stephen K.  Employee  $179,700.00   Per Annum
# 11               Barger, Lara R.  Employee   $83,000.00   Per Annum
# 12                 Bash, John F.  Employee  $130,000.00   Per Annum
# ...
